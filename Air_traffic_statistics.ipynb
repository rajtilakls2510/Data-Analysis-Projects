# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib as mpl
import seaborn as sns
# %matplotlib inline
mpl.style.use('ggplot')

# %% [markdown]
# # Introduction

# %% [markdown]
# This Data Science project is over a couple of datasets. The first dataset consists of the data of all the aircrafts landing at San Francisco form 2002 to 2018. The other dataset consists of the data of all the airplanes and its passenger counts at SF either deplaned, enplaned or through the airport.

# %%
landings=pd.read_csv('air-traffic-landings-statistics.csv')
passengers=pd.read_csv('air-traffic-passenger-statistics.csv')

# %%
landings.head()
# Out:
#    Activity Period                        Operating Airline  \
# 0           200204                             ATA Airlines
# 1           200204                             ATA Airlines
# 2           200204                             ATA Airlines
# 3           200204  Aeroflot Russian International Airlines
# 4           200204                               Air Canada
#
#   Operating Airline IATA Code                        Published Airline  \
# 0                          TZ                             ATA Airlines
# 1                          TZ                             ATA Airlines
# 2                          TZ                             ATA Airlines
# 3                         NaN  Aeroflot Russian International Airlines
# 4                          AC                               Air Canada
#
#   Published Airline IATA Code    GEO Summary GEO Region Landing Aircraft Type  \
# 0                          TZ       Domestic         US             Passenger
# 1                          TZ       Domestic         US             Passenger
# 2                          TZ       Domestic         US             Passenger
# 3                         NaN  International     Europe             Passenger
# 4                          AC  International     Canada             Passenger
#
#   Aircraft Body Type Aircraft Manufacturer Aircraft Model Aircraft Version  \
# 0        Narrow Body                Boeing            757              200
# 1        Narrow Body                Boeing            757              300
# 2          Wide Body              Lockheed          L1011                0
# 3          Wide Body                Boeing            777                0
# 4        Narrow Body                Boeing            737              200
#
#    Landing Count  Total Landed Weight
# 0             83             16434000
# 1              3               672000
# 2             27              9666000
# 3              9              4139946
# 4              5               525000

# %%
passengers.head()
# Out:
#    Activity Period Operating Airline Operating Airline IATA Code  \
# 0           200507      ATA Airlines                          TZ
# 1           200507      ATA Airlines                          TZ
# 2           200507      ATA Airlines                          TZ
# 3           200507        Air Canada                          AC
# 4           200507        Air Canada                          AC
#
#   Published Airline Published Airline IATA Code    GEO Summary GEO Region  \
# 0      ATA Airlines                          TZ       Domestic         US
# 1      ATA Airlines                          TZ       Domestic         US
# 2      ATA Airlines                          TZ       Domestic         US
# 3        Air Canada                          AC  International     Canada
# 4        Air Canada                          AC  International     Canada
#
#   Activity Type Code Price Category Code    Terminal Boarding Area  \
# 0           Deplaned            Low Fare  Terminal 1             B
# 1           Enplaned            Low Fare  Terminal 1             B
# 2     Thru / Transit            Low Fare  Terminal 1             B
# 3           Deplaned               Other  Terminal 1             B
# 4           Enplaned               Other  Terminal 1             B
#
#    Passenger Count
# 0            27271
# 1            29131
# 2             5415
# 3            35156
# 4            34090

# %% [markdown]
# # Missing Data

# %%
landings['Aircraft Version'].replace(np.nan,0,inplace=True)

# %%
landings['Aircraft Manufacturer'].replace(np.nan,landings['Aircraft Manufacturer'].value_counts().idxmax(),inplace=True)

# %% [markdown]
# # Analysis(Landings)

# %%
#1 Which airline lands its heaviest planes over a period (2007-2017)
#2 Bar graph of the landing count distribution in each year of the airline with most number of international flights
#3 Area graph over the context of landing count distribution in years of the top 5 airlines which perform most domestic flights(2007-17)
#4 Which is the top aircraft manufacturer which top 5 frighter airlines choose to perform their flights to SF 
#5 Which aircraft manufacturer makes a freighter aircraft which can carry more weight than others

# %%
#1 
# Airline with most weight
dec_7_17=landings[landings['Activity Period']>200700 ]
dec_7_17=dec_7_17[dec_7_17['Activity Period']<201800]
dec_7_17.groupby("Operating Airline")['Total Landed Weight'].agg('mean').sort_values(ascending=False).head(1)
# Out:
# Operating Airline
# Virgin America    5.735168e+07
# Name: Total Landed Weight, dtype: float64

# %% [markdown]
# Virgin America is the airline which has the highest average landing weight in the decade 2007-2017

# %%
virgin=dec_7_17[dec_7_17['Operating Airline']=='Virgin America']
virgin['Activity Period']=virgin['Activity Period'].astype('str')
# Out:
# C:\Users\The WonderlanD\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
virgin['year']=virgin['Activity Period'].str.slice(0,4)
virgin['year']=virgin['year'].astype('int')
virgin
# Out:
# C:\Users\The WonderlanD\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\The WonderlanD\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#       Activity Period Operating Airline Operating Airline IATA Code  \
# 3653           200708    Virgin America                          VX
# 3793           200709    Virgin America                          VX
# 3931           200710    Virgin America                          VX
# 3932           200710    Virgin America                          VX
# 4066           200711    Virgin America                          VX
# 4067           200711    Virgin America                          VX
# 4202           200712    Virgin America                          VX
# 4203           200712    Virgin America                          VX
# 4342           200801    Virgin America                          VX
# 4343           200801    Virgin America                          VX
# 4467           200802    Virgin America                          VX
# 4468           200802    Virgin America                          VX
# 4601           200803    Virgin America                          VX
# 4602           200803    Virgin America                          VX
# 4736           200804    Virgin America                          VX
# 4737           200804    Virgin America                          VX
# 4867           200805    Virgin America                          VX
# 4868           200805    Virgin America                          VX
# 5000           200806    Virgin America                          VX
# 5001           200806    Virgin America                          VX
# 5135           200807    Virgin America                          VX
# 5136           200807    Virgin America                          VX
# 5275           200808    Virgin America                          VX
# 5276           200808    Virgin America                          VX
# 5414           200809    Virgin America                          VX
# 5415           200809    Virgin America                          VX
# 5543           200810    Virgin America                          VX
# 5544           200810    Virgin America                          VX
# 5677           200811    Virgin America                          VX
# 5678           200811    Virgin America                          VX
# ...               ...               ...                         ...
# 19947          201706    Virgin America                          VX
# 19948          201706    Virgin America                          VX
# 19949          201706    Virgin America                          VX
# 20109          201707    Virgin America                          VX
# 20110          201707    Virgin America                          VX
# 20111          201707    Virgin America                          VX
# 20112          201707    Virgin America                          VX
# 20277          201708    Virgin America                          VX
# 20278          201708    Virgin America                          VX
# 20279          201708    Virgin America                          VX
# 20280          201708    Virgin America                          VX
# 20435          201709    Virgin America                          VX
# 20436          201709    Virgin America                          VX
# 20437          201709    Virgin America                          VX
# 20438          201709    Virgin America                          VX
# 20439          201709    Virgin America                          VX
# 20612          201710    Virgin America                          VX
# 20613          201710    Virgin America                          VX
# 20614          201710    Virgin America                          VX
# 20615          201710    Virgin America                          VX
# 20769          201711    Virgin America                          VX
# 20770          201711    Virgin America                          VX
# 20771          201711    Virgin America                          VX
# 20772          201711    Virgin America                          VX
# 20773          201711    Virgin America                          VX
# 20919          201712    Virgin America                          VX
# 20920          201712    Virgin America                          VX
# 20921          201712    Virgin America                          VX
# 20922          201712    Virgin America                          VX
# 20923          201712    Virgin America                          VX
#
#       Published Airline Published Airline IATA Code    GEO Summary GEO Region  \
# 3653     Virgin America                          VX       Domestic         US
# 3793     Virgin America                          VX       Domestic         US
# 3931     Virgin America                          VX       Domestic         US
# 3932     Virgin America                          VX       Domestic         US
# 4066     Virgin America                          VX       Domestic         US
# 4067     Virgin America                          VX       Domestic         US
# 4202     Virgin America                          VX       Domestic         US
# 4203     Virgin America                          VX       Domestic         US
# 4342     Virgin America                          VX       Domestic         US
# 4343     Virgin America                          VX       Domestic         US
# 4467     Virgin America                          VX       Domestic         US
# 4468     Virgin America                          VX       Domestic         US
# 4601     Virgin America                          VX       Domestic         US
# 4602     Virgin America                          VX       Domestic         US
# 4736     Virgin America                          VX       Domestic         US
# 4737     Virgin America                          VX       Domestic         US
# 4867     Virgin America                          VX       Domestic         US
# 4868     Virgin America                          VX       Domestic         US
# 5000     Virgin America                          VX       Domestic         US
# 5001     Virgin America                          VX       Domestic         US
# 5135     Virgin America                          VX       Domestic         US
# 5136     Virgin America                          VX       Domestic         US
# 5275     Virgin America                          VX       Domestic         US
# 5276     Virgin America                          VX       Domestic         US
# 5414     Virgin America                          VX       Domestic         US
# 5415     Virgin America                          VX       Domestic         US
# 5543     Virgin America                          VX       Domestic         US
# 5544     Virgin America                          VX       Domestic         US
# 5677     Virgin America                          VX       Domestic         US
# 5678     Virgin America                          VX       Domestic         US
# ...                 ...                         ...            ...        ...
# 19947    Virgin America                          VX       Domestic         US
# 19948    Virgin America                          VX  International     Mexico
# 19949    Virgin America                          VX  International         US
# 20109    Virgin America                          VX       Domestic         US
# 20110    Virgin America                          VX       Domestic         US
# 20111    Virgin America                          VX  International     Mexico
# 20112    Virgin America                          VX  International         US
# 20277    Virgin America                          VX       Domestic         US
# 20278    Virgin America                          VX       Domestic         US
# 20279    Virgin America                          VX  International     Mexico
# 20280    Virgin America                          VX  International         US
# 20435    Virgin America                          VX       Domestic         US
# 20436    Virgin America                          VX  International     Mexico
# 20437    Virgin America                          VX       Domestic         US
# 20438    Virgin America                          VX  International     Mexico
# 20439    Virgin America                          VX  International         US
# 20612    Virgin America                          VX       Domestic         US
# 20613    Virgin America                          VX       Domestic         US
# 20614    Virgin America                          VX  International     Mexico
# 20615    Virgin America                          VX  International         US
# 20769    Virgin America                          VX       Domestic         US
# 20770    Virgin America                          VX  International     Mexico
# 20771    Virgin America                          VX       Domestic         US
# 20772    Virgin America                          VX  International     Mexico
# 20773    Virgin America                          VX  International         US
# 20919    Virgin America                          VX       Domestic         US
# 20920    Virgin America                          VX  International     Mexico
# 20921    Virgin America                          VX       Domestic         US
# 20922    Virgin America                          VX  International     Mexico
# 20923    Virgin America                          VX  International         US
#
#       Landing Aircraft Type Aircraft Body Type Aircraft Manufacturer  \
# 3653              Passenger        Narrow Body                Airbus
# 3793              Passenger        Narrow Body                Airbus
# 3931              Passenger        Narrow Body                Airbus
# 3932              Passenger        Narrow Body                Airbus
# 4066              Passenger        Narrow Body                Airbus
# 4067              Passenger        Narrow Body                Airbus
# 4202              Passenger        Narrow Body                Airbus
# 4203              Passenger        Narrow Body                Airbus
# 4342              Passenger        Narrow Body                Airbus
# 4343              Passenger        Narrow Body                Airbus
# 4467              Passenger        Narrow Body                Airbus
# 4468              Passenger        Narrow Body                Airbus
# 4601              Passenger        Narrow Body                Airbus
# 4602              Passenger        Narrow Body                Airbus
# 4736              Passenger        Narrow Body                Airbus
# 4737              Passenger        Narrow Body                Airbus
# 4867              Passenger        Narrow Body                Airbus
# 4868              Passenger        Narrow Body                Airbus
# 5000              Passenger        Narrow Body                Airbus
# 5001              Passenger        Narrow Body                Airbus
# 5135              Passenger        Narrow Body                Airbus
# 5136              Passenger        Narrow Body                Airbus
# 5275              Passenger        Narrow Body                Airbus
# 5276              Passenger        Narrow Body                Airbus
# 5414              Passenger        Narrow Body                Airbus
# 5415              Passenger        Narrow Body                Airbus
# 5543              Passenger        Narrow Body                Airbus
# 5544              Passenger        Narrow Body                Airbus
# 5677              Passenger        Narrow Body                Airbus
# 5678              Passenger        Narrow Body                Airbus
# ...                     ...                ...                   ...
# 19947             Passenger        Narrow Body                Airbus
# 19948             Passenger        Narrow Body                Airbus
# 19949             Passenger        Narrow Body                Airbus
# 20109             Passenger        Narrow Body                Airbus
# 20110             Passenger        Narrow Body                Airbus
# 20111             Passenger        Narrow Body                Airbus
# 20112             Passenger        Narrow Body                Airbus
# 20277             Passenger        Narrow Body                Airbus
# 20278             Passenger        Narrow Body                Airbus
# 20279             Passenger        Narrow Body                Airbus
# 20280             Passenger        Narrow Body                Airbus
# 20435             Passenger        Narrow Body                Airbus
# 20436             Passenger        Narrow Body                Airbus
# 20437             Passenger        Narrow Body                Airbus
# 20438             Passenger        Narrow Body                Airbus
# 20439             Passenger        Narrow Body                Airbus
# 20612             Passenger        Narrow Body                Airbus
# 20613             Passenger        Narrow Body                Airbus
# 20614             Passenger        Narrow Body                Airbus
# 20615             Passenger        Narrow Body                Airbus
# 20769             Passenger        Narrow Body                Airbus
# 20770             Passenger        Narrow Body                Airbus
# 20771             Passenger        Narrow Body                Airbus
# 20772             Passenger        Narrow Body                Airbus
# 20773             Passenger        Narrow Body                Airbus
# 20919             Passenger        Narrow Body                Airbus
# 20920             Passenger        Narrow Body                Airbus
# 20921             Passenger        Narrow Body                Airbus
# 20922             Passenger        Narrow Body                Airbus
# 20923             Passenger        Narrow Body                Airbus
#
#       Aircraft Model Aircraft Version  Landing Count  Total Landed Weight  \
# 3653            A320                0            179             25453800
# 3793            A320                0            261             37114200
# 3931            A319                0              3               413400
# 3932            A320                0            388             55173600
# 4066            A319                0             85             11713000
# 4067            A320                0            341             48490200
# 4202            A319                0             65              8957000
# 4203            A320                0            395             56169000
# 4342            A319                0             62              8543600
# 4343            A320                0            392             55742400
# 4467            A319                0             90             12402000
# 4468            A320                0            407             57875400
# 4601            A319                0            200             27560000
# 4602            A320                0            464             65980800
# 4736            A319                0            220             30316000
# 4737            A320                0            518             73659600
# 4867            A319                0            346             47678800
# 4868            A320                0            439             62425800
# 5000            A319                0            371             51123800
# 5001            A320                0            436             61999200
# 5135            A319                0            446             61458800
# 5136            A320                0            456             64843200
# 5275            A319                -            450             62010000
# 5276            A320                -            426             60577200
# 5414            A319                -            294             40513200
# 5415            A320                -            413             58728600
# 5543            A319                -            263             36241400
# 5544            A320                -            467             66407400
# 5677            A319                -            279             38446200
# 5678            A320                -            454             64558800
# ...              ...              ...            ...                  ...
# 19947           A320                -           1614            230536049
# 19948           A320                -             41              5853267
# 19949           A321                -             50              8730300
# 20109           A319                -            185             25490780
# 20110           A320                -           1633            233320486
# 20111           A320                -             45              6402217
# 20112           A321                -             63             11000178
# 20277           A319                -            185             25490780
# 20278           A320                -           1653            236137990
# 20279           A320                -             36              5135663
# 20280           A321                -             57              9952542
# 20435           A319                -            245             33758060
# 20436           A319                -              1               137788
# 20437           A320                -           1542            220221732
# 20438           A320                -             20              2847267
# 20439           A321                -             61             10650966
# 20612           A319                -            268             36927184
# 20613           A320                -           1618            231151139
# 20614           A320                -             26              3707069
# 20615           A321                -             72             12571632
# 20769           A319                -            262             36100456
# 20770           A319                -             11              1515668
# 20771           A320                -           1609            229758919
# 20772           A320                -             48              6878416
# 20773           A321                -             84             14666904
# 20919           A319                -            258             35549304
# 20920           A319                -             13              1791244
# 20921           A320                -           1676            239438307
# 20922           A320                -             69              9871188
# 20923           A321                -             96             16762176
#
#        year
# 3653   2007
# 3793   2007
# 3931   2007
# 3932   2007
# 4066   2007
# 4067   2007
# 4202   2007
# 4203   2007
# 4342   2008
# 4343   2008
# 4467   2008
# 4468   2008
# 4601   2008
# 4602   2008
# 4736   2008
# 4737   2008
# 4867   2008
# 4868   2008
# 5000   2008
# 5001   2008
# 5135   2008
# 5136   2008
# 5275   2008
# 5276   2008
# 5414   2008
# 5415   2008
# 5543   2008
# 5544   2008
# 5677   2008
# 5678   2008
# ...     ...
# 19947  2017
# 19948  2017
# 19949  2017
# 20109  2017
# 20110  2017
# 20111  2017
# 20112  2017
# 20277  2017
# 20278  2017
# 20279  2017
# 20280  2017
# 20435  2017
# 20436  2017
# 20437  2017
# 20438  2017
# 20439  2017
# 20612  2017
# 20613  2017
# 20614  2017
# 20615  2017
# 20769  2017
# 20770  2017
# 20771  2017
# 20772  2017
# 20773  2017
# 20919  2017
# 20920  2017
# 20921  2017
# 20922  2017
# 20923  2017
#
# [394 rows x 15 columns]

# %%
virgin.groupby('year',as_index=False)['Total Landed Weight'].agg('sum').set_index('year').plot(kind='bar',figsize=(10,5))
plt.title('Landing Weight Distribution of Virgin America')
plt.ylabel('Landing Weight(x10^8)')
plt.show()

# %% [markdown]
# This graph depicts the rise of Virgin America in San Francisco. It had a great rise in 2012 and ultimately passed the 3x10^8 mark in 2017.

# %%
#2 
inter=dec_7_17[dec_7_17['GEO Summary']=='International']
inter.groupby('Operating Airline')['Landing Count'].agg('sum').sort_values(ascending=False).head()
# Out:
# Operating Airline
# United Airlines - Pre 07/01/2013    44236
# United Airlines                     38976
# Air Canada                          34308
# SkyWest Airlines                    25105
# Alaska Airlines                     10278
# Name: Landing Count, dtype: int64

# %% [markdown]
# It can be seen that there is some problem with the United Airlines entry. There are two entries: United Airlines and United Airlines Pre 07/01/2013.And both are the airlines with maximum number of landings at SF.

# %%
united=inter[(inter['Operating Airline']=='United Airlines') | (inter['Operating Airline']=='United Airlines - Pre 07/01/2013')]
united['Activity Period']=united['Activity Period'].astype('str')
united['year']=united['Activity Period'].str.slice(0,4)
united['year']=united['year'].astype('int')
united.groupby('year')['Landing Count'].agg('sum').plot(kind='bar')
plt.title('United Airlines Landing Count')
plt.ylabel('Landing Count')
plt.show()
# Out:
# C:\Users\The WonderlanD\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\The WonderlanD\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\The WonderlanD\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %% [markdown]
# United Airlines is the airline which has most number of landings at SF. Its landing count, in the decade 2007 to 2017, is depicted in this graph. Its landing count first decreased till 2009-2010 but continued to increase till 2017 when it crossed the 10000 mark ultimately showing its dominance over other airlines operating at SF.

# %%
#3 
top_air=dec_7_17[dec_7_17['GEO Summary']=="Domestic"].groupby('Operating Airline',as_index=False)['Landing Count'].agg('sum').sort_values('Landing Count',ascending=False).reset_index().head()
top_air
# Out:
#    index                 Operating Airline  Landing Count
# 0     35                  SkyWest Airlines         463958
# 1     44                   United Airlines         285863
# 2     45  United Airlines - Pre 07/01/2013         251029
# 3     47                    Virgin America         155329
# 4     37                Southwest Airlines         151422

# %% [markdown]
# These are the top 5 Domestic airlines which perform most landings at SF.

# %%
air=list(top_air.drop_duplicates(subset='Operating Airline',keep='last')['Operating Airline'])
top_air=dec_7_17[((dec_7_17['Operating Airline']==air[0])|(dec_7_17['Operating Airline']==air[1])|(dec_7_17['Operating Airline']==air[2])|(dec_7_17['Operating Airline']==air[3])|(dec_7_17['Operating Airline']==air[4]))&(dec_7_17['GEO Summary']=='Domestic')]

# %%
top_air['Activity Period']=top_air['Activity Period'].astype('str')
top_air['year']=top_air['Activity Period'].str.slice(0,4)
top_air['year']=top_air['year'].astype('int')
# Out:
# C:\Users\The WonderlanD\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\The WonderlanD\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\The WonderlanD\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
top_air.groupby(['year','Operating Airline'],as_index=False)['Landing Count'].agg('sum').pivot_table(index='Operating Airline',columns='year',values='Landing Count').transpose().plot(kind='area',stacked=False,alpha=0.5,figsize=(20,10))
plt.title('Landing trend of Top 5 Domestic Airlines at SF')
plt.ylabel('No. of landings')
plt.show()

# %% [markdown]
# This graph shows that SkyWest Airlines, which is the best Domestic Airline, had its landings maximum in the year 2012. After that it is continuously losing its position. Since there was a problem with the entry of United Airlines, let us consider the pre2013 first and then the actual, to be the continuation of the graph of United Airlines. On analysing, we get that United Airlines is gaining its popularity in SF with growing years and is going to be the number 1 in the upcoming years. While United is busy maintaing its position, Virgin America and Southwest Airlines are fighting their own market. The growing graphs of the former mentioned airlines show that they have tough competition among themselves and are fighting their way out. While Southwest has not seen any growth in its landings in the later part of the decade, Virgin has a very slow rate of growth in every three years.

# %%
#4
top_freighter=dec_7_17[dec_7_17['Landing Aircraft Type']=='Freighter'].groupby('Operating Airline',as_index=False)['Landing Count'].agg('sum').sort_values('Landing Count',ascending=False).head()
top_freighter
# Out:
#         Operating Airline  Landing Count
# 16        Federal Express           5691
# 0                 ABX Air           5489
# 22       Korean Air Lines           3904
# 4             Ameriflight           3814
# 23  Nippon Cargo Airlines           3381

# %% [markdown]
# Federal Express is the top freighter airline followed by ABX Air and so on.

# %%
dec_7_17[(dec_7_17['Operating Airline']=='Federal Express')|(dec_7_17['Operating Airline']=='ABX Air')|(dec_7_17['Operating Airline']=='Korean Air Lines')|(dec_7_17['Operating Airline']=='Nippon Cargo Airlines')|(dec_7_17['Operating Airline']=='Ameriflight')].groupby(['Operating Airline','Aircraft Manufacturer'],as_index=False)['Landing Count'].agg('count')
# Out:
#         Operating Airline Aircraft Manufacturer  Landing Count
# 0                 ABX Air                Boeing            114
# 1                 ABX Air     McDonnell Douglas             26
# 2             Ameriflight              BAE-Avro              4
# 3             Ameriflight            Beechcraft            164
# 4             Ameriflight             Fairchild             59
# 5             Ameriflight               LearJet             11
# 6             Ameriflight                 Piper              6
# 7         Federal Express                Airbus            177
# 8         Federal Express                Boeing             26
# 9         Federal Express     McDonnell Douglas            174
# 10       Korean Air Lines                Boeing            437
# 11  Nippon Cargo Airlines                Boeing            177

# %% [markdown]
# Looks like the leader: Federal Express prefers Airbus and McDonnell Douglas while Korean Airlines and Nippon Cargo Airlines believe in Boeing. ABX Air also belives in Boeing. Sice Ameriflight is a small cargo airline ar SF, buying Boeing cargo planes are not possible for it. That's why it uses Beechcraft more, which is a small aircraft.

# %%
dec_7_17[dec_7_17['Landing Aircraft Type']=='Freighter'].groupby('Aircraft Manufacturer')['Total Landed Weight'].agg('sum').sort_values(ascending=False)
# Out:
# Aircraft Manufacturer
# Boeing               12955682215
# McDonnell Douglas     1609811490
# Airbus                 498999470
# Shorts                  37622000
# Beechcraft              30624280
# Fairchild               20846000
# Cessna                   3281000
# LearJet                   260100
# Piper                      67500
# BAE-Avro                   62500
# Name: Total Landed Weight, dtype: int64

# %% [markdown]
# Looks like Boeing is the company which manufactures aircrafts which carries more weight than other companies' aircrafts.

# %%
# Let us find which aircraft of Boeing carries the most weight
dec_7_17[(dec_7_17['Aircraft Manufacturer']=="Boeing")&(dec_7_17['Landing Aircraft Type']=='Freighter')].groupby(['Aircraft Model','Aircraft Version'],as_index=False)['Total Landed Weight'].agg('sum').sort_values('Total Landed Weight',ascending=False)
# Out:
#    Aircraft Model Aircraft Version  Total Landed Weight
# 14            747             400F           5144785200
# 16            747              800           1515862970
# 20            767                -           1347259000
# 26           B744                -            887627000
# 9             747              400            875069398
# 27           B748                -            848518000
# 6             747              200            632520000
# 3             747                0            401168000
# 13            747           400ERF            371557000
# 29           B762                -            230939000
# 19            767                0            221589000
# 30           B763                -            201128000
# 21            767              300            104266000
# 12            747            400ER             71177000
# 7             747             200F             29610000
# 2             737              300             24602600
# 31           B772                -              9775000
# 10            747           400BCF              9324000
# 23           A124                -              5092500
# 25           B742                -              5040000
# 22            777                F              4600000
# 24         AN-124              100              3079525
# 5             747              100              2945000
# 18            757            200PF              2520000
# 4             747                -              1332000
# 0             727              200               964000
# 11            747             400E               666000
# 15            747            412SF               652022
# 8             747             246F               630000
# 28           B752                -               630000
# 17            757              200               594000
# 1             727              400               160000

# %% [markdown]
# # Passenger data

# %%
passengers.head()
# Out:
#    Activity Period Operating Airline Operating Airline IATA Code  \
# 0           200507      ATA Airlines                          TZ
# 1           200507      ATA Airlines                          TZ
# 2           200507      ATA Airlines                          TZ
# 3           200507        Air Canada                          AC
# 4           200507        Air Canada                          AC
#
#   Published Airline Published Airline IATA Code    GEO Summary GEO Region  \
# 0      ATA Airlines                          TZ       Domestic         US
# 1      ATA Airlines                          TZ       Domestic         US
# 2      ATA Airlines                          TZ       Domestic         US
# 3        Air Canada                          AC  International     Canada
# 4        Air Canada                          AC  International     Canada
#
#   Activity Type Code Price Category Code    Terminal Boarding Area  \
# 0           Deplaned            Low Fare  Terminal 1             B
# 1           Enplaned            Low Fare  Terminal 1             B
# 2     Thru / Transit            Low Fare  Terminal 1             B
# 3           Deplaned               Other  Terminal 1             B
# 4           Enplaned               Other  Terminal 1             B
#
#    Passenger Count
# 0            27271
# 1            29131
# 2             5415
# 3            35156
# 4            34090

# %% [markdown]
# # Missing data

# %%
passengers.isnull().sum()
# Out:
# Activity Period                 0
# Operating Airline               0
# Operating Airline IATA Code    63
# Published Airline               0
# Published Airline IATA Code    63
# GEO Summary                     0
# GEO Region                      0
# Activity Type Code              0
# Price Category Code             0
# Terminal                        0
# Boarding Area                   0
# Passenger Count                 0
# dtype: int64

# %% [markdown]
# No missing data other than IATA code which is of no use to us.

# %% [markdown]
# # Analysis

# %%
#1 Bar graph of the total number of passengers travelling through SF in each year in the period(2007-17)
#2 Which Terminal of SF handles maximum passengers over a course of 10years(7-17)(Area graph)
#3 Bar graph comparison of passengers deplaned, enplaned and thru/transit at SF per year(7-17)
#4 Which domestic airline is at its peak in its business per year(7-17)
#5 To which international GEO region do the passengers of SF travel most per year(7-17) and give its distribution of passenger count in heatmap of top 5 airlines

# %% [markdown]
# Since all the analysis are to be done in the decade 2007-17, let us slice out the decade from the total data.

# %%
pax7_17=passengers[(passengers['Activity Period']>200700) & (passengers['Activity Period']<201800)]
pax7_17
# Out:
#        Activity Period        Operating Airline Operating Airline IATA Code  \
# 2064            200701             ATA Airlines                          TZ
# 2065            200701             ATA Airlines                          TZ
# 2066            200701               Air Canada                          AC
# 2067            200701               Air Canada                          AC
# 2068            200701                Air China                          CA
# 2069            200701                Air China                          CA
# 2070            200701               Air France                          AF
# 2071            200701               Air France                          AF
# 2072            200701          Air New Zealand                          NZ
# 2073            200701          Air New Zealand                          NZ
# 2074            200701          AirTran Airways                          FL
# 2075            200701          AirTran Airways                          FL
# 2076            200701          Alaska Airlines                          AS
# 2077            200701          Alaska Airlines                          AS
# 2078            200701          Alaska Airlines                          AS
# 2079            200701          Alaska Airlines                          AS
# 2080            200701          Alaska Airlines                          AS
# 2081            200701          Alaska Airlines                          AS
# 2082            200701          Alaska Airlines                          AS
# 2083            200701          Alaska Airlines                          AS
# 2084            200701          Alaska Airlines                          AS
# 2085            200701       All Nippon Airways                          NH
# 2086            200701       All Nippon Airways                          NH
# 2087            200701        American Airlines                          AA
# 2088            200701        American Airlines                          AA
# 2089            200701  American Eagle Airlines                          MQ
# 2090            200701  American Eagle Airlines                          MQ
# 2091            200701              Ameriflight                          A8
# 2092            200701          Asiana Airlines                          OZ
# 2093            200701          Asiana Airlines                          OZ
# ...                ...                      ...                         ...
# 17929           201712          United Airlines                          UA
# 17930           201712          United Airlines                          UA
# 17931           201712          United Airlines                          UA
# 17932           201712          United Airlines                          UA
# 17933           201712          United Airlines                          UA
# 17934           201712          United Airlines                          UA
# 17935           201712          United Airlines                          UA
# 17936           201712          United Airlines                          UA
# 17937           201712          United Airlines                          UA
# 17938           201712          United Airlines                          UA
# 17939           201712          United Airlines                          UA
# 17940           201712          United Airlines                          UA
# 17941           201712          United Airlines                          UA
# 17942           201712          United Airlines                          UA
# 17943           201712          United Airlines                          UA
# 17944           201712          United Airlines                          UA
# 17945           201712          United Airlines                          UA
# 17946           201712          United Airlines                          UA
# 17947           201712          United Airlines                          UA
# 17948           201712          United Airlines                          UA
# 17949           201712           Virgin America                          VX
# 17950           201712           Virgin America                          VX
# 17951           201712           Virgin America                          VX
# 17952           201712           Virgin America                          VX
# 17953           201712          Virgin Atlantic                          VS
# 17954           201712          Virgin Atlantic                          VS
# 17955           201712         Volaris Airlines                          Y4
# 17956           201712         Volaris Airlines                          Y4
# 17957           201712                  WOW Air                          WW
# 17958           201712                  WOW Air                          WW
#
#         Published Airline Published Airline IATA Code    GEO Summary  \
# 2064         ATA Airlines                          TZ       Domestic
# 2065         ATA Airlines                          TZ       Domestic
# 2066           Air Canada                          AC  International
# 2067           Air Canada                          AC  International
# 2068            Air China                          CA  International
# 2069            Air China                          CA  International
# 2070           Air France                          AF  International
# 2071           Air France                          AF  International
# 2072      Air New Zealand                          NZ  International
# 2073      Air New Zealand                          NZ  International
# 2074      AirTran Airways                          FL       Domestic
# 2075      AirTran Airways                          FL       Domestic
# 2076      Alaska Airlines                          AS       Domestic
# 2077      Alaska Airlines                          AS       Domestic
# 2078      Alaska Airlines                          AS       Domestic
# 2079      Alaska Airlines                          AS  International
# 2080      Alaska Airlines                          AS  International
# 2081      Alaska Airlines                          AS  International
# 2082      Alaska Airlines                          AS  International
# 2083      Alaska Airlines                          AS  International
# 2084      Alaska Airlines                          AS  International
# 2085   All Nippon Airways                          NH  International
# 2086   All Nippon Airways                          NH  International
# 2087    American Airlines                          AA       Domestic
# 2088    American Airlines                          AA       Domestic
# 2089    American Airlines                          AA       Domestic
# 2090    American Airlines                          AA       Domestic
# 2091          Ameriflight                          A8       Domestic
# 2092      Asiana Airlines                          OZ  International
# 2093      Asiana Airlines                          OZ  International
# ...                   ...                         ...            ...
# 17929     United Airlines                          UA       Domestic
# 17930     United Airlines                          UA       Domestic
# 17931     United Airlines                          UA  International
# 17932     United Airlines                          UA  International
# 17933     United Airlines                          UA  International
# 17934     United Airlines                          UA  International
# 17935     United Airlines                          UA  International
# 17936     United Airlines                          UA  International
# 17937     United Airlines                          UA  International
# 17938     United Airlines                          UA  International
# 17939     United Airlines                          UA  International
# 17940     United Airlines                          UA  International
# 17941     United Airlines                          UA  International
# 17942     United Airlines                          UA  International
# 17943     United Airlines                          UA  International
# 17944     United Airlines                          UA  International
# 17945     United Airlines                          UA  International
# 17946     United Airlines                          UA  International
# 17947     United Airlines                          UA  International
# 17948     United Airlines                          UA  International
# 17949      Virgin America                          VX       Domestic
# 17950      Virgin America                          VX       Domestic
# 17951      Virgin America                          VX  International
# 17952      Virgin America                          VX  International
# 17953     Virgin Atlantic                          VS  International
# 17954     Virgin Atlantic                          VS  International
# 17955    Volaris Airlines                          Y4  International
# 17956    Volaris Airlines                          Y4  International
# 17957             WOW Air                          WW  International
# 17958             WOW Air                          WW  International
#
#                 GEO Region Activity Type Code Price Category Code  \
# 2064                    US           Deplaned            Low Fare
# 2065                    US           Enplaned            Low Fare
# 2066                Canada           Deplaned               Other
# 2067                Canada           Enplaned               Other
# 2068                  Asia           Deplaned               Other
# 2069                  Asia           Enplaned               Other
# 2070                Europe           Deplaned               Other
# 2071                Europe           Enplaned               Other
# 2072   Australia / Oceania           Deplaned               Other
# 2073   Australia / Oceania           Enplaned               Other
# 2074                    US           Deplaned            Low Fare
# 2075                    US           Enplaned            Low Fare
# 2076                    US           Deplaned               Other
# 2077                    US           Enplaned               Other
# 2078                    US     Thru / Transit               Other
# 2079                Canada           Deplaned               Other
# 2080                Canada           Enplaned               Other
# 2081                Canada     Thru / Transit               Other
# 2082                Mexico           Deplaned               Other
# 2083                Mexico           Enplaned               Other
# 2084                Mexico     Thru / Transit               Other
# 2085                  Asia           Deplaned               Other
# 2086                  Asia           Enplaned               Other
# 2087                    US           Deplaned               Other
# 2088                    US           Enplaned               Other
# 2089                    US           Deplaned               Other
# 2090                    US           Enplaned               Other
# 2091                    US           Enplaned               Other
# 2092                  Asia           Deplaned               Other
# 2093                  Asia           Enplaned               Other
# ...                    ...                ...                 ...
# 17929                   US           Enplaned               Other
# 17930                   US     Thru / Transit               Other
# 17931                 Asia           Deplaned               Other
# 17932                 Asia           Enplaned               Other
# 17933  Australia / Oceania           Deplaned               Other
# 17934  Australia / Oceania           Enplaned               Other
# 17935               Canada           Deplaned               Other
# 17936               Canada           Enplaned               Other
# 17937               Canada           Deplaned               Other
# 17938               Canada           Enplaned               Other
# 17939               Canada           Deplaned               Other
# 17940               Canada           Enplaned               Other
# 17941               Europe           Deplaned               Other
# 17942               Europe           Enplaned               Other
# 17943               Mexico           Deplaned               Other
# 17944               Mexico           Enplaned               Other
# 17945               Mexico           Enplaned               Other
# 17946               Mexico           Enplaned               Other
# 17947          Middle East           Deplaned               Other
# 17948          Middle East           Enplaned               Other
# 17949                   US           Deplaned            Low Fare
# 17950                   US           Enplaned            Low Fare
# 17951               Mexico           Deplaned            Low Fare
# 17952               Mexico           Enplaned            Low Fare
# 17953               Europe           Deplaned               Other
# 17954               Europe           Enplaned               Other
# 17955               Mexico           Deplaned            Low Fare
# 17956               Mexico           Enplaned            Low Fare
# 17957               Europe           Enplaned               Other
# 17958               Europe           Deplaned               Other
#
#             Terminal Boarding Area  Passenger Count
# 2064   International             A               48
# 2065   International             A               48
# 2066      Terminal 3             E            19541
# 2067      Terminal 3             E            18824
# 2068   International             G             4845
# 2069   International             G             4397
# 2070   International             A             7200
# 2071   International             A             6473
# 2072   International             G             9254
# 2073   International             G             9969
# 2074      Terminal 1             B             4171
# 2075      Terminal 1             B             4141
# 2076      Terminal 1             B            35595
# 2077      Terminal 1             B            35845
# 2078      Terminal 1             B             2260
# 2079      Terminal 1             B             2846
# 2080      Terminal 1             B             5199
# 2081      Terminal 1             B             1661
# 2082   International             A            12645
# 2083   International             A            11399
# 2084   International             A             1460
# 2085   International             G             6144
# 2086   International             G             5189
# 2087      Terminal 3             E           124647
# 2088      Terminal 3             E           116955
# 2089      Terminal 3             E             3042
# 2090      Terminal 3             E             2576
# 2091           Other         Other               10
# 2092   International             A             4952
# 2093   International             A             3526
# ...              ...           ...              ...
# 17929     Terminal 3             F           430593
# 17930     Terminal 3             F               34
# 17931  International             G            68533
# 17932  International             G            79890
# 17933  International             G            16576
# 17934  International             G            15737
# 17935  International             G              426
# 17936  International             G              775
# 17937     Terminal 3             E             6462
# 17938     Terminal 3             E             4471
# 17939     Terminal 3             F             4957
# 17940     Terminal 3             F             7413
# 17941  International             G            21144
# 17942  International             G            23230
# 17943  International             G            33251
# 17944  International             G             9718
# 17945     Terminal 3             E             3486
# 17946     Terminal 3             F            25241
# 17947  International             G             5525
# 17948  International             G             5876
# 17949     Terminal 2             D           224879
# 17950     Terminal 2             D           238226
# 17951  International             A             8525
# 17952     Terminal 2             D             9846
# 17953  International             A             9600
# 17954  International             A            11512
# 17955  International             A             3221
# 17956  International             A             5415
# 17957  International             A             3800
# 17958  International             G             3113
#
# [15895 rows x 12 columns]

# %%
# 1
#let us create a column of years
pax7_17['years']=pax7_17['Activity Period'].astype('str').str.slice(0,4)
pax7_17['years']=pax7_17['years'].astype('int')
pax7_17
# Out:
# C:\Users\The WonderlanD\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\The WonderlanD\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
#        Activity Period        Operating Airline Operating Airline IATA Code  \
# 2064            200701             ATA Airlines                          TZ
# 2065            200701             ATA Airlines                          TZ
# 2066            200701               Air Canada                          AC
# 2067            200701               Air Canada                          AC
# 2068            200701                Air China                          CA
# 2069            200701                Air China                          CA
# 2070            200701               Air France                          AF
# 2071            200701               Air France                          AF
# 2072            200701          Air New Zealand                          NZ
# 2073            200701          Air New Zealand                          NZ
# 2074            200701          AirTran Airways                          FL
# 2075            200701          AirTran Airways                          FL
# 2076            200701          Alaska Airlines                          AS
# 2077            200701          Alaska Airlines                          AS
# 2078            200701          Alaska Airlines                          AS
# 2079            200701          Alaska Airlines                          AS
# 2080            200701          Alaska Airlines                          AS
# 2081            200701          Alaska Airlines                          AS
# 2082            200701          Alaska Airlines                          AS
# 2083            200701          Alaska Airlines                          AS
# 2084            200701          Alaska Airlines                          AS
# 2085            200701       All Nippon Airways                          NH
# 2086            200701       All Nippon Airways                          NH
# 2087            200701        American Airlines                          AA
# 2088            200701        American Airlines                          AA
# 2089            200701  American Eagle Airlines                          MQ
# 2090            200701  American Eagle Airlines                          MQ
# 2091            200701              Ameriflight                          A8
# 2092            200701          Asiana Airlines                          OZ
# 2093            200701          Asiana Airlines                          OZ
# ...                ...                      ...                         ...
# 17929           201712          United Airlines                          UA
# 17930           201712          United Airlines                          UA
# 17931           201712          United Airlines                          UA
# 17932           201712          United Airlines                          UA
# 17933           201712          United Airlines                          UA
# 17934           201712          United Airlines                          UA
# 17935           201712          United Airlines                          UA
# 17936           201712          United Airlines                          UA
# 17937           201712          United Airlines                          UA
# 17938           201712          United Airlines                          UA
# 17939           201712          United Airlines                          UA
# 17940           201712          United Airlines                          UA
# 17941           201712          United Airlines                          UA
# 17942           201712          United Airlines                          UA
# 17943           201712          United Airlines                          UA
# 17944           201712          United Airlines                          UA
# 17945           201712          United Airlines                          UA
# 17946           201712          United Airlines                          UA
# 17947           201712          United Airlines                          UA
# 17948           201712          United Airlines                          UA
# 17949           201712           Virgin America                          VX
# 17950           201712           Virgin America                          VX
# 17951           201712           Virgin America                          VX
# 17952           201712           Virgin America                          VX
# 17953           201712          Virgin Atlantic                          VS
# 17954           201712          Virgin Atlantic                          VS
# 17955           201712         Volaris Airlines                          Y4
# 17956           201712         Volaris Airlines                          Y4
# 17957           201712                  WOW Air                          WW
# 17958           201712                  WOW Air                          WW
#
#         Published Airline Published Airline IATA Code    GEO Summary  \
# 2064         ATA Airlines                          TZ       Domestic
# 2065         ATA Airlines                          TZ       Domestic
# 2066           Air Canada                          AC  International
# 2067           Air Canada                          AC  International
# 2068            Air China                          CA  International
# 2069            Air China                          CA  International
# 2070           Air France                          AF  International
# 2071           Air France                          AF  International
# 2072      Air New Zealand                          NZ  International
# 2073      Air New Zealand                          NZ  International
# 2074      AirTran Airways                          FL       Domestic
# 2075      AirTran Airways                          FL       Domestic
# 2076      Alaska Airlines                          AS       Domestic
# 2077      Alaska Airlines                          AS       Domestic
# 2078      Alaska Airlines                          AS       Domestic
# 2079      Alaska Airlines                          AS  International
# 2080      Alaska Airlines                          AS  International
# 2081      Alaska Airlines                          AS  International
# 2082      Alaska Airlines                          AS  International
# 2083      Alaska Airlines                          AS  International
# 2084      Alaska Airlines                          AS  International
# 2085   All Nippon Airways                          NH  International
# 2086   All Nippon Airways                          NH  International
# 2087    American Airlines                          AA       Domestic
# 2088    American Airlines                          AA       Domestic
# 2089    American Airlines                          AA       Domestic
# 2090    American Airlines                          AA       Domestic
# 2091          Ameriflight                          A8       Domestic
# 2092      Asiana Airlines                          OZ  International
# 2093      Asiana Airlines                          OZ  International
# ...                   ...                         ...            ...
# 17929     United Airlines                          UA       Domestic
# 17930     United Airlines                          UA       Domestic
# 17931     United Airlines                          UA  International
# 17932     United Airlines                          UA  International
# 17933     United Airlines                          UA  International
# 17934     United Airlines                          UA  International
# 17935     United Airlines                          UA  International
# 17936     United Airlines                          UA  International
# 17937     United Airlines                          UA  International
# 17938     United Airlines                          UA  International
# 17939     United Airlines                          UA  International
# 17940     United Airlines                          UA  International
# 17941     United Airlines                          UA  International
# 17942     United Airlines                          UA  International
# 17943     United Airlines                          UA  International
# 17944     United Airlines                          UA  International
# 17945     United Airlines                          UA  International
# 17946     United Airlines                          UA  International
# 17947     United Airlines                          UA  International
# 17948     United Airlines                          UA  International
# 17949      Virgin America                          VX       Domestic
# 17950      Virgin America                          VX       Domestic
# 17951      Virgin America                          VX  International
# 17952      Virgin America                          VX  International
# 17953     Virgin Atlantic                          VS  International
# 17954     Virgin Atlantic                          VS  International
# 17955    Volaris Airlines                          Y4  International
# 17956    Volaris Airlines                          Y4  International
# 17957             WOW Air                          WW  International
# 17958             WOW Air                          WW  International
#
#                 GEO Region Activity Type Code Price Category Code  \
# 2064                    US           Deplaned            Low Fare
# 2065                    US           Enplaned            Low Fare
# 2066                Canada           Deplaned               Other
# 2067                Canada           Enplaned               Other
# 2068                  Asia           Deplaned               Other
# 2069                  Asia           Enplaned               Other
# 2070                Europe           Deplaned               Other
# 2071                Europe           Enplaned               Other
# 2072   Australia / Oceania           Deplaned               Other
# 2073   Australia / Oceania           Enplaned               Other
# 2074                    US           Deplaned            Low Fare
# 2075                    US           Enplaned            Low Fare
# 2076                    US           Deplaned               Other
# 2077                    US           Enplaned               Other
# 2078                    US     Thru / Transit               Other
# 2079                Canada           Deplaned               Other
# 2080                Canada           Enplaned               Other
# 2081                Canada     Thru / Transit               Other
# 2082                Mexico           Deplaned               Other
# 2083                Mexico           Enplaned               Other
# 2084                Mexico     Thru / Transit               Other
# 2085                  Asia           Deplaned               Other
# 2086                  Asia           Enplaned               Other
# 2087                    US           Deplaned               Other
# 2088                    US           Enplaned               Other
# 2089                    US           Deplaned               Other
# 2090                    US           Enplaned               Other
# 2091                    US           Enplaned               Other
# 2092                  Asia           Deplaned               Other
# 2093                  Asia           Enplaned               Other
# ...                    ...                ...                 ...
# 17929                   US           Enplaned               Other
# 17930                   US     Thru / Transit               Other
# 17931                 Asia           Deplaned               Other
# 17932                 Asia           Enplaned               Other
# 17933  Australia / Oceania           Deplaned               Other
# 17934  Australia / Oceania           Enplaned               Other
# 17935               Canada           Deplaned               Other
# 17936               Canada           Enplaned               Other
# 17937               Canada           Deplaned               Other
# 17938               Canada           Enplaned               Other
# 17939               Canada           Deplaned               Other
# 17940               Canada           Enplaned               Other
# 17941               Europe           Deplaned               Other
# 17942               Europe           Enplaned               Other
# 17943               Mexico           Deplaned               Other
# 17944               Mexico           Enplaned               Other
# 17945               Mexico           Enplaned               Other
# 17946               Mexico           Enplaned               Other
# 17947          Middle East           Deplaned               Other
# 17948          Middle East           Enplaned               Other
# 17949                   US           Deplaned            Low Fare
# 17950                   US           Enplaned            Low Fare
# 17951               Mexico           Deplaned            Low Fare
# 17952               Mexico           Enplaned            Low Fare
# 17953               Europe           Deplaned               Other
# 17954               Europe           Enplaned               Other
# 17955               Mexico           Deplaned            Low Fare
# 17956               Mexico           Enplaned            Low Fare
# 17957               Europe           Enplaned               Other
# 17958               Europe           Deplaned               Other
#
#             Terminal Boarding Area  Passenger Count  years
# 2064   International             A               48   2007
# 2065   International             A               48   2007
# 2066      Terminal 3             E            19541   2007
# 2067      Terminal 3             E            18824   2007
# 2068   International             G             4845   2007
# 2069   International             G             4397   2007
# 2070   International             A             7200   2007
# 2071   International             A             6473   2007
# 2072   International             G             9254   2007
# 2073   International             G             9969   2007
# 2074      Terminal 1             B             4171   2007
# 2075      Terminal 1             B             4141   2007
# 2076      Terminal 1             B            35595   2007
# 2077      Terminal 1             B            35845   2007
# 2078      Terminal 1             B             2260   2007
# 2079      Terminal 1             B             2846   2007
# 2080      Terminal 1             B             5199   2007
# 2081      Terminal 1             B             1661   2007
# 2082   International             A            12645   2007
# 2083   International             A            11399   2007
# 2084   International             A             1460   2007
# 2085   International             G             6144   2007
# 2086   International             G             5189   2007
# 2087      Terminal 3             E           124647   2007
# 2088      Terminal 3             E           116955   2007
# 2089      Terminal 3             E             3042   2007
# 2090      Terminal 3             E             2576   2007
# 2091           Other         Other               10   2007
# 2092   International             A             4952   2007
# 2093   International             A             3526   2007
# ...              ...           ...              ...    ...
# 17929     Terminal 3             F           430593   2017
# 17930     Terminal 3             F               34   2017
# 17931  International             G            68533   2017
# 17932  International             G            79890   2017
# 17933  International             G            16576   2017
# 17934  International             G            15737   2017
# 17935  International             G              426   2017
# 17936  International             G              775   2017
# 17937     Terminal 3             E             6462   2017
# 17938     Terminal 3             E             4471   2017
# 17939     Terminal 3             F             4957   2017
# 17940     Terminal 3             F             7413   2017
# 17941  International             G            21144   2017
# 17942  International             G            23230   2017
# 17943  International             G            33251   2017
# 17944  International             G             9718   2017
# 17945     Terminal 3             E             3486   2017
# 17946     Terminal 3             F            25241   2017
# 17947  International             G             5525   2017
# 17948  International             G             5876   2017
# 17949     Terminal 2             D           224879   2017
# 17950     Terminal 2             D           238226   2017
# 17951  International             A             8525   2017
# 17952     Terminal 2             D             9846   2017
# 17953  International             A             9600   2017
# 17954  International             A            11512   2017
# 17955  International             A             3221   2017
# 17956  International             A             5415   2017
# 17957  International             A             3800   2017
# 17958  International             G             3113   2017
#
# [15895 rows x 13 columns]

# %%
pax7_17.groupby('years',as_index=False)['Passenger Count'].agg('sum').set_index('years').plot(kind='bar',figsize=(10,5))
plt.title('Passengers per year')
plt.ylabel('No. of passengers in x10^7')
plt.xlabel('Years')
plt.show()

# %% [markdown]
# As it can be visualized from the graph that at 2007 the passenger count was around 35 million and it slowly increased as the decade proceeded and touched the 50 million mark in 2015 and is soon going to get to 60 million in either the end of 2018 or mid 2019.

# %%
# 2
terminals=passengers.groupby('Terminal',as_index=False)['Passenger Count'].agg('sum').set_index('Terminal').sort_values('Passenger Count',ascending=False)
terminals.plot(kind='pie',figsize=(10,5),autopct='%1.2f%%',subplots=True,labels=None,shadow=True)
plt.title('Representing percentage of passengers handled by each terminal at SF')
plt.ylabel('')
plt.axis('equal')
plt.legend(labels=terminals.index,loc='upper left')
plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# Terminal3 handles almost 40% of the passengers at SF followed by the international terminal, which handles almost 27% of the passengers. The 'others' terminal has a very very low value and might posssibly be the General Aviation Terminal. We will later find out why Terminal3 has such a load.

# %%
# 3
pax=pax7_17.groupby(['years','Activity Type Code'],as_index=False)['Passenger Count'].agg('sum').set_index('years')

# %%
deplaned=pax[pax['Activity Type Code']=='Deplaned']
enplaned=pax[pax['Activity Type Code']=='Enplaned']
thru=pax[pax['Activity Type Code']=='Thru / Transit']
barwidth=0.35
fig,ax=plt.subplots(figsize=(10,10))
p1=plt.bar(deplaned.index,deplaned["Passenger Count"],barwidth,label='Deplaned')
p2=plt.bar(enplaned.index+barwidth,enplaned['Passenger Count'],barwidth,label="Enplaned")
p3=plt.bar(thru.index+(barwidth*2),thru['Passenger Count'],barwidth,label='Thru/Transit')
plt.title('Comparison between passengers Deplaned, Enplaned and Thru at SF per year')
plt.ylabel('No. of passengers')
plt.xlabel('Years')
plt.xticks(deplaned.index+barwidth,deplaned.index)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# Above graph shows that the number of passengers that deplane and enplane at SF are almost equal. Both of the numbers go on increasing as the years pass by. We see that the passengers that go through SF are almost equal to none. This is because of an intersting fact. In earlier days, as the engines of the airplanes were not so powerful, HUB System was used in Aviation. HUB System simply represents that if any plane has to go from an airport to another airport which are far away from each other, they had to give stops at imtermediate airports due to several reasons. That might be Refueling or other stuff like short maintenence. Now these intermediate airports were big airports like SF. So planes used to get a stop at SF and then continue with its journey, thereby increasing the number of Through passengers at SF. Now a days, HUB System is no longer used as the engines of the planes are pwerful enough to cover long distant flights in one leg. That's why the number of through passengers are continuously decreasing at SF. But you might question that if HUB System is no longer in use, why do passengers(even a small amount) go through SF? Imgaine an airport near to SF but does not have an infrastructure to handle international traffic. Any passenger, trying to reach an international destination has to make a transition through SF( as SF is the only international airport near the small one) to reach his/her destination.

# %%
# 4
#First let us find the airline at SF which rules the domestic passenger service
pax7_17[pax7_17['GEO Summary']=='Domestic'].groupby('Operating Airline',as_index=False)['Passenger Count'].agg('sum').sort_values('Passenger Count',ascending=False).head(6)
# Out:
#                    Operating Airline  Passenger Count
# 30                   United Airlines         83749648
# 31  United Airlines - Pre 07/01/2013         64752856
# 4                  American Airlines         36720763
# 23                  SkyWest Airlines         36035376
# 32                    Virgin America         35271113
# 24                Southwest Airlines         31559719

# %% [markdown]
# It was seen from the other data that Skywest performed most landings at SF but from this data we get that United Airlines(combined) carries maximum number of passengers. This might be because of the bigger airplanes preffered by United which can carry more passengers than Skywest Airlines. But here, American Airlines has occupied the 2nd(virtually) position. The combined score of both the united airlines is way higher than that of other airlines.

# %%
# Passenger distribution of American airlines
domestic=pax7_17[pax7_17['GEO Summary']=='Domestic']
american=domestic[(domestic['Operating Airline']=='American Airlines')]
american.groupby(['Operating Airline','years'],as_index=False)['Passenger Count'].agg('sum').set_index('years').plot(figsize=(10,10))
plt.title('Passenger Distribution of American Airlines')
plt.ylabel('No. of passengers')
plt.xlabel('Years')
plt.show()

# %% [markdown]
# It can be visualized from the graph that the business of American Airlines was falling like anything and became least in 2014. Now, it is very interesting to see that the passenger count of American Airlines touched the 4400000 mark from less than 3000000 in a couple of years. It would be really interesting to know what American Airlines did to have such a sudden increase in its business.

# %%
# 5
#First lets get the top international destination
pax7_17[pax7_17['GEO Summary']=='International'].groupby('GEO Region',as_index=False)['Passenger Count'].agg('sum').sort_values('Passenger Count',ascending=False).head()
# Out:
#             GEO Region  Passenger Count
# 0                 Asia         47062442
# 4               Europe         29783590
# 2               Canada         15017168
# 5               Mexico          9297433
# 1  Australia / Oceania          5216849

# %% [markdown]
# Asia is the international GEO Region where people travel most from SF

# %%
#Lets find the top 5 airlines which carry maximum passengers to Asia.
pax7_17[pax7_17['GEO Region']=='Asia'].groupby('Operating Airline',as_index=False)['Passenger Count'].agg('sum').sort_values('Passenger Count',ascending=False).head(7)
# Out:
#                    Operating Airline  Passenger Count
# 18  United Airlines - Pre 07/01/2013         10307100
# 17                   United Airlines          7823360
# 4                     Cathay Pacific          4904493
# 15                Singapore Airlines          3779724
# 9                        EVA Airways          3682442
# 14               Philippine Airlines          2747803
# 5                     China Airlines          2590543

# %%
#Since United Airlines has a very peculiar distribution and its count is so much that we cannot overlook it, we will try to rename all United Airlines Pre 7/1/13 to United Airlines
pax7_17['Operating Airline'].replace('United Airlines - Pre 07/01/2013','United Airlines',inplace=True)
# Out:
# C:\Users\The WonderlanD\Anaconda3\lib\site-packages\pandas\core\generic.py:5886: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)

# %%
pax7_17[pax7_17['GEO Region']=='Asia'].groupby('Operating Airline',as_index=False)['Passenger Count'].agg('sum').sort_values('Passenger Count',ascending=False).head()['Operating Airline']
# Out:
# 17        United Airlines
# 4          Cathay Pacific
# 15     Singapore Airlines
# 9             EVA Airways
# 14    Philippine Airlines
# Name: Operating Airline, dtype: object

# %% [markdown]
# Therefore we have all the united airlines entry with one name

# %%
# now lets find the passenger distribution of these airlines to Asia
international=pax7_17[((pax7_17['Operating Airline']=='United Airlines')|(pax7_17['Operating Airline']=='Cathay Pacific')|(pax7_17['Operating Airline']=='Singapore Airlines')|(pax7_17['Operating Airline']=='EVA Airways')|(pax7_17['Operating Airline']=='Philippine Airlines'))&(pax7_17['GEO Region']=='Asia')]

# %%
pivot=international.groupby(['Operating Airline','years'],as_index=False)['Passenger Count'].agg('sum').set_index('years').pivot_table(index='Operating Airline',columns='years',values='Passenger Count')

# %%
sns.heatmap(pivot)
plt.title('Heatmap of each airline vs passengers')
plt.show()

# %% [markdown]
# As seen from earlier that United Airlines rule in Domestic part. Now it can be seen that United Airlines also rules the international market from SF.
# 1.We can see that United suffered some downfall in its passenger count in 2009 and 2013 but soon regained its position in the years following that.
# 2.Cathay Pacific has maintained its consistency in its business throughout the decade, but is facing some downfall now.
# 3.EVA Airways is rising in the 2nd half of the decade.
# 4.Phillipine Airlines has not done much business throughout the decade.
# 5.Singapore Airlines is also struggling to stay in the competition but has suffered a little bit downfall in the passenger count at the end of the decade.

# %% [markdown]
# # Conclusion

# %% [markdown]
# From the analysis of both of the datasets we get that Virgin America is the airline which has the highest average landing weight in the decade 2007-2017, United Airlines is the airline which has most number of landings at SF, Landing trend of Top 5 Domestic Airlines at SF, Federal Express is the top freighter airline followed by ABX Air and so on, Federal Express prefers Airbus and McDonnell Douglas while Korean Airlines and Nippon Cargo Airlines believe in Boeing, Boeing is the company which manufactures aircrafts which carries more weight than other companies' aircrafts, Boeing 747 400F can carry a weight way greater than any other airplane,  the passenger count at SF each year, SF's Terminal3 handles most of the traffic, the decrease in the number of through passengers at SF due to the less usage of HUB System in aviation, passenger distribution of American Airlines and the passenger distribution of the top 5 international airlines operating at SF to Asia. United Airlines rule over the domestic and international market in carrying passengers at SF.

# %% [markdown]
# # Thank you for having a look at this project
